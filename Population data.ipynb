# %% [markdown]
# # code the population of Kenya since 1950-2023

# %%
import pandas as pd
from ydata_profiling import ProfileReport
import matplotlib.pyplot as plt
import matplotlib_inline.backend_inline
import seaborn as sns

# %%
df1=pd.read_csv('kenyan population since 1950-2023.csv')
df1
# Out:
#       Year  Population Yearly %     Yearly Migrants (net)  Median Age  \
# 0      NaN         NaN   Change     Change            NaN         NaN
# 1   2023.0  55,100,586    1.99%  1,073,099        -10,000        19.6
# 2   2022.0  54,027,487    1.93%  1,021,873        -10,000        19.4
# 3   2020.0  51,985,780    2.03%  1,034,330        -17,106        18.9
# 4   2015.0  46,851,488    2.45%  1,066,719        -95,981        17.9
# 5   2010.0  41,517,895    2.98%  1,134,977        -21,076        17.0
# 6   2005.0  35,843,010    3.04%    998,281          5,496        16.4
# 7   2000.0  30,851,606    2.80%    794,652          5,407        15.6
# 8   1995.0  26,878,347    3.02%    743,216        -75,544        14.9
# 9   1990.0  23,162,269    3.55%    742,022        -11,341        14.3
# 10  1985.0  19,452,161    3.74%    653,007        -35,416        13.8
# 11  1980.0  16,187,124    3.47%    507,043        -39,943        13.3
# ...

# %%
def highlight_cells(val):
    if isinstance(val, (int, float)):
        return 'background-color: yellow' if val > 1 else ""
    return ''
highlighted_data = df1.style.applymap(highlight_cells)
highlighted_data
# Out:
# <style type="text/css">
# ...

# %%
df1.nunique()
# Out:
# Year                  16
# Population            16
# Yearly %              17
# Yearly                17
# Migrants (net)        15
# Median Age            15
# Fertility Rate        16
# Density (P/Km²        16
# Urban                 17
# Urban Population      16
# Country's Share of    16
# World Population      16
# Kenya                 14
# dtype: int64

# %%
df1.std()
# Out:
# C:\Users\keric\AppData\Local\Temp\ipykernel_4908\3039516898.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.std()
# Year              22.849872
# Median Age         2.237474
# Fertility Rate     1.851163
# Density (P/Km²    30.423675
# dtype: float64

# %%
df1.sum()
# Out:
# C:\Users\keric\AppData\Local\Temp\ipykernel_4908\2390510930.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.sum()
# Year                                                            31870.0
# Yearly %              Change1.99%1.93%2.03%2.45%2.98%3.04%2.80%3.02%...
# Yearly                Change1,073,0991,021,8731,034,3301,066,7191,13...
# Median Age                                                        251.7
# Fertility Rate                                                    93.15
# Density (P/Km²                                                    792.0
# Urban                 Pop %30.70%30.10%28.80%25.90%23.50%21.80%20.30...
# Country's Share of    World Pop0.68%0.68%0.66%0.63%0.59%0.55%0.50%0....
# Kenya                       Global Rank26272729313333353640414546625862
# dtype: object

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                16 non-null     float64
#  1   Population          16 non-null     object
#  2   Yearly %            17 non-null     object
#  3   Yearly              17 non-null     object
#  4   Migrants (net)      16 non-null     object
#  5   Median Age          16 non-null     float64
#  6   Fertility Rate      16 non-null     float64
#  7   Density (P/Km²      16 non-null     float64
#  8   Urban               17 non-null     object
#  9   Urban Population    16 non-null     object
#  10  Country's Share of  17 non-null     object
#  11  World Population    16 non-null     object
#  12  Kenya               17 non-null     object
# dtypes: float64(4), object(9)
# memory usage: 1.9+ KB

# %%
sns.boxplot(y=df1["Density (P/Km²"])
plt.grid(True)

plt.show()

# %%
df1.describe()
# Out:
#               Year  Median Age  Fertility Rate  Density (P/Km²
# count    16.000000   16.000000       16.000000       16.000000
# mean   1991.875000   15.731250        5.821875       49.500000
# std      22.849872    2.237474        1.851163       30.423675
# min    1955.000000   13.100000        3.240000       12.000000
# 25%    1973.750000   13.875000        4.227500       23.000000
# 50%    1992.500000   15.250000        5.750000       44.000000
# 75%    2011.250000   17.225000        7.607500       75.250000
# max    2023.000000   19.600000        8.030000       97.000000

# %%
p=ProfileReport(df1, title='Profile Report')
p
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling vv4.3.1&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2023-11-22 07:40:40.025809&quot;&gt;&lt;title&gt;Profile Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
df1.sort_values('Year')
# Out:
#       Year  Population Yearly %     Yearly Migrants (net)  Median Age  \
# 16  1955.0   6,558,870    2.58%    156,964         -4,336        15.7
# 15  1960.0   7,751,435    3.40%    238,513          2,140        14.6
# 14  1965.0   9,417,207    3.97%    333,154          8,524        13.9
# 13  1970.0  11,473,087    4.03%    411,176        -13,059        13.3
# 12  1975.0  13,651,908    3.54%    435,764        -71,454        13.1
# 11  1980.0  16,187,124    3.47%    507,043        -39,943        13.3
# 10  1985.0  19,452,161    3.74%    653,007        -35,416        13.8
# 9   1990.0  23,162,269    3.55%    742,022        -11,341        14.3
# 8   1995.0  26,878,347    3.02%    743,216        -75,544        14.9
# 7   2000.0  30,851,606    2.80%    794,652          5,407        15.6
# 6   2005.0  35,843,010    3.04%    998,281          5,496        16.4
# 5   2010.0  41,517,895    2.98%  1,134,977        -21,076        17.0
# ...

# %%
df1.median()
# Out:
# C:\Users\keric\AppData\Local\Temp\ipykernel_16032\2279417019.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.median()
# Year              1992.50
# Median Age          15.25
# Fertility Rate       5.75
# Density (P/Km²      44.00
# dtype: float64

# %%
df1.dtypes
# Out:
# Year                  float64
# Population             object
# Yearly %               object
# Yearly                 object
# Migrants (net)         object
# Median Age            float64
# Fertility Rate        float64
# Density (P/Km²        float64
# Urban                  object
# Urban Population       object
# Country's Share of     object
# World Population       object
# Kenya                  object
# dtype: object

# %%
df1.quantile(0.25)
# Out:
# Year              1973.7500
# Median Age          13.8750
# Fertility Rate       4.2275
# Density (P/Km²      23.0000
# Name: 0.25, dtype: float64

# %%
df1.quantile(0.75)
# Out:
# Year              2011.2500
# Median Age          17.2250
# Fertility Rate       7.6075
# Density (P/Km²      75.2500
# Name: 0.75, dtype: float64

# %%
def detect_outliers(df, column):
    data = df[column]
    # Calculate the first quartile (Q1) and third quartile (Q3)
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)

    # Calculate the interquartile range (IQR)
    IQR = Q3 - Q1

    # Define the lower and upper bounds to identify outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Find outliers
    outliers = df[(data < lower_bound) | (data > upper_bound)]

    return outliers

# Example usage:
outliers = detect_outliers(df1, 'Density (P/Km²')
outliers
# Out:
# Empty DataFrame
# Columns: [Year, Population, Yearly %, Yearly, Migrants (net), Median Age, Fertility Rate, Density (P/Km², Urban, Urban Population, Country's Share of, World Population, Kenya]
# Index: []

# %%
df1.isnull().sum()
# Out:
# Year                  1
# Population            1
# Yearly %              0
# Yearly                0
# Migrants (net)        1
# Median Age            1
# Fertility Rate        1
# Density (P/Km²        1
# Urban                 0
# Urban Population      1
# Country's Share of    0
# World Population      1
# Kenya                 0
# dtype: int64

# %%
df1.isna().sum()
# Out:
# Year                  1
# Population            1
# Yearly %              0
# Yearly                0
# Migrants (net)        1
# Median Age            1
# Fertility Rate        1
# Density (P/Km²        1
# Urban                 0
# Urban Population      1
# Country's Share of    0
# World Population      1
# Kenya                 0
# dtype: int64

# %%
from scipy.stats import zscore
x=df1["Fertility Rate"]
z=zscore(x)
z
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# Name: Fertility Rate, dtype: float64
